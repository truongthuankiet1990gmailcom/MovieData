# %%
import pandas as pd
from requests_html import HTMLSession
from bs4 import BeautifulSoup
import re

# %%
def clean_text(text):
    """Function to clean text by removing newline characters and anything after"""
    return re.sub(r'\n.*', '', text).strip()

def add_data_from_csv(movie_data_file, budget_data_file):
    data = pd.DataFrame(columns=['Name', 'Year', 'CriticScore', 'UserScore', 'Link', 'PlatformReleased', 'Cast', 'Director', 'Genre', 'Rating', 'Runtime', 'Studio'])
    
    # Load the movie data and budget data
    movie_data = pd.read_csv(movie_data_file)
    budget_data = pd.read_csv(budget_data_file)
    
    # Extract the movie names from the budget data
    movie_names = budget_data['Movie Name'].values
    
    for movie_name in movie_names:
        # Check if movie_name is a valid string
        if isinstance(movie_name, str):
            # Check if the movie is already in the dataset
            if movie_name not in movie_data['Name'].values:
                title = movie_name
                # Replace space with underscore for the URL and make it lowercase and remove characters ':' and '.'
                movie_name = movie_name.lower().replace(':', '').replace('.', '').replace(' ', '_').replace('','')
                
                url = f"https://www.rottentomatoes.com/m/{movie_name}"
                session = HTMLSession()
                response = session.get(url)
                
                if response.status_code == 200:
                    print(f"Processing {title}")
                    soup = BeautifulSoup(response.content, 'html.parser')
                    
                    CriticScore = soup.find('rt-button', {'slot': 'criticsScore'}).text.strip() if soup.find('rt-button', {'slot': 'criticsScore'}) else 'N/A'
                    year = soup.find('rt-text', {'slot': 'releaseDate'}).text.strip() if soup.find('rt-text', {'slot': 'releaseDate'}) else 'N/A'
                    UserScore = soup.find('rt-button', {'slot': 'audienceScore'}).text.strip() if soup.find('rt-button', {'slot': 'audienceScore'}) else 'N/A'
                    
                    people = soup.find_all('a', href=lambda href: href and "/celebrity/" in href)
                    roles = soup.find_all('p', {'data-qa': 'person-role'})
                    
                    cast = []
                    director = None
                    for person, role in zip(people, roles):
                        role_text = role.text.strip()
                        person_name = clean_text(person.text.strip())
                        if role_text == 'Director':
                            director = person_name
                        else:
                            cast.append(f"{person_name}")
                    
                    cast_str = ', '.join(cast) if cast else 'N/A'
                    director = director if director else 'N/A'
                    rating = soup.find('rt-text', {'slot': 'ratingsCode'}).text.strip() if soup.find('rt-text', {'slot': 'ratingsCode'}) else 'N/A'
                    runtime = soup.find('rt-text', {'slot': 'duration'}).text.strip() if soup.find('rt-text', {'slot': 'duration'}) else 'N/A'
                    studio_element = soup.find('rt-text', {'data-qa': 'item-value'})
                    studio = studio_element.text.strip() if studio_element else 'N/A'
                    
                    genre_elements = soup.find_all('rt-link', href=lambda href: href and '/genres' in href)
                    genres = [genre.text.strip() for genre in genre_elements]
                    genre_str = ', '.join(genres) if genres else 'N/A'
                    
                    # Add the movie data to the DataFrame
                    new_data = pd.DataFrame({'Name': [title], 'Year': [year], 'CriticScore': [CriticScore], 'UserScore': [UserScore], 
                                             'Link': [url], 'PlatformReleased': ['Cinema'], 'Cast': [cast_str], 'Director': [director],
                                             'Genre': [genre_str], 'Rating': [rating], 'Runtime': [runtime], 'Studio': [studio]})
                    data = pd.concat([data, new_data], ignore_index=True)
        else:
            print(f"Skipping invalid movie name: {movie_name}")
    
    return data

# Call the function and print the titles

# %%
movies_data1 = add_data_from_csv('../../Data/Matched_movie.csv', '../../Data/movie_budgets_name_fixed.csv')
movies_data = pd.read_csv('../../Data/Matched_movie.csv')
movies_data = pd.concat([movies_data, movies_data1], ignore_index=True)
(movies_data)

# %%
movies_data = movies_data.drop(columns=['Unnamed: 0'])

# %%
movies_data.to_csv('../../Data/updated_movies.csv', index=False)

# %%
# After checking duplicates, remove it and fix the duplicate name and year released
movies_data = pd.read_csv('../../Data/updated_movies.csv')
movies_data = movies_data.drop_duplicates(keep='first')
movies_data.to_csv('../../Data/updated_movies.csv', index=False)

# %%
movies_data
# Out:
#                                Name                   Year CriticScore  \
# 0                 L.A. Confidential                 (1997)         99%
# 1                     The Godfather                 (1972)         97%
# 2                        Casablanca                 (1942)         99%
# 3                          Parasite                 (2019)         99%
# 4                  Schindler's List                 (1993)         98%
# ...                             ...                    ...         ...
# 5014                      Following   Released Apr 2, 1998         82%
# 5015  Return to the Land of Wonders  Released Apr 27, 2004         NaN
# 5016           A Plague So Pleasant                   2013         NaN
# 5017              My Date With Drew  Released Sep 16, 2005         72%
# 5018                         Neeras                   2021         NaN
#
#      UserScore                                               Link  \
# 0          94%   https://www.rottentomatoes.com/m/la_confidential
# 1          98%     https://www.rottentomatoes.com/m/the_godfather
# 2          95%  https://www.rottentomatoes.com/m/1003707-casab...
# 3          90%     https://www.rottentomatoes.com/m/parasite_2019
# 4          97%   https://www.rottentomatoes.com/m/schindlers_list
# ...        ...                                                ...
# 5014       85%         https://www.rottentomatoes.com/m/following
# 5015       NaN  https://www.rottentomatoes.com/m/return_to_the...
# 5016       60%  https://www.rottentomatoes.com/m/a_plague_so_p...
# 5017       57%  https://www.rottentomatoes.com/m/my_date_with_...
# 5018       NaN            https://www.rottentomatoes.com/m/neeras
#
#      PlatformReleased                                               Cast  \
# 0              Cinema  Kevin Spacey, Russell Crowe, Guy Pearce, James...
# 1              Cinema  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2              Cinema  Humphrey Bogart, Ingrid Bergman, Paul Henreid,...
# 3              Cinema  Song Kang-ho, Lee Sun-kyun, Jo Yeo-jeong, Choi...
# 4              Cinema  Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...
# ...               ...                                                ...
# 5014           Cinema  Jeremy Theobald, Alex Haw, Lucy Russell, John ...
# 5015           Cinema  Maysoon Pachachi, Maysoon Pachachi, Anne Even,...
# 5016           Cinema  Eva Boehnke, David Chandler, Maxwell Moody, Be...
# 5017           Cinema       Drew Barrymore, John August, Allison Burnett
# 5018           Cinema       Achyut Prashast Singh, Achyut Prashast Singh
#
#                    Director                              Genre Rating Runtime  \
# 0             Curtis Hanson                       Crime, Drama      R  2h 16m
# 1      Francis Ford Coppola                       Crime, Drama      R  2h 57m
# 2            Michael Curtiz                              Drama     PG  1h 42m
# 3              Bong Joon Ho  Comedy, Mystery & Thriller, Drama      R  2h 12m
# 4          Steven Spielberg                     History, Drama      R  3h 15m
# ...                     ...                                ...    ...     ...
# 5014      Christopher Nolan                 Mystery & Thriller      R   1h 9m
# 5015       Maysoon Pachachi                        Documentary    NaN  1h 28m
# 5016           Jordan Reyes  Drama, Horror, Mystery & Thriller    NaN  1h 16m
# 5017             Brett Winn                        Documentary     PG  1h 30m
# 5018  Achyut Prashast Singh  Action, Mystery & Thriller, Crime    NaN     10m
#
#                          Studio
# 0             Warner Home Vídeo
# 1            Paramount Pictures
# 2         Warner Bros. Pictures
# 3                          Neon
# 4            Universal Pictures
# ...                         ...
# 5014           Columbia Tristar
# 5015             Oxymoron Films
# 5016                    English
# 5017  Slowhand Cinema Releasing
# 5018                    English
#
# [4865 rows x 12 columns]

# %%
movies_data = add_data_from_csv('../../Data/updated_movies.csv', '../../Data/movie_budgets_name_fixed (2).csv')
movies_data
# Out:
# Processing SpiderMan 3
# Processing Guardians of the Galaxy Vol 3
# Processing Iron Man 3
# Processing Guardians of the Galaxy Vol 2
# Processing SpiderMan 2
# Processing Cars 2
# Processing 2012
# Processing Wonder Woman 1984
# Processing Furious 7
# Processing Blade Runner 2049
# Processing Rush Hour 3
# Processing Cars 3
# Processing 47 Ronin
# Processing Iron Man 2
# Processing Terminator 3: Rise of the Machines
# Processing Big Hero 6
# Processing Fast and Furious 6
# Processing Madagascar: Escape 2 Africa
# Processing 6 Underground
# Processing Kung Fu Panda 3
# Processing Lethal Weapon 4
# Processing The Twilight Saga: Breaking Dawn Part 2
# Processing Rio 2
# Processing Meg 2: The Trench
# Processing The Twilight Saga: Breaking Dawn Part 1
# Processing Mission: Impossible 2
# Processing Stuart Little 2
# Processing Deadpool 2
# Processing 300: Rise of an Empire
# Processing The Smurfs 2
# Processing Speed 2: Cruise Control
# Processing Around the World in 80 Days
# Processing 10000 B.C.
# Processing Despicable Me 4
# Processing Terminator 2: Judgment Day
# Processing The Expendables 2
# Processing The Expendables 3
# Processing Expend4bles
# Processing The LEGO Movie 2: The Second Part
# Processing Sex and the City 2
# Processing Rush Hour 2
# Processing Now You See Me 2
# Processing K19: The Widowmaker
# Processing The Nutcracker in 3D
# Processing Kung Fu Panda 4
# Processing Sing 2
# Processing 102 Dalmatians
# Processing RED 2
# Processing The 6th Day
# Processing Hotel Transylvania 2
# Processing The Secret Life of Pets 2
# Processing Grown Ups 2
# Processing Fantasia 2000
# Processing Journey 2: The Mysterious Island
# Processing Cloudy with a Chance of Meatballs 2
# Processing The Equalizer 2
# Processing Despicable Me 2
# Processing 2 Fast 2 Furious
# Processing Despicable Me 3
# Processing 50 First Dates
# Processing The 355
# Processing Devara Part 1
# Processing Dr. Dolittle 2
# Processing Shrek 2
# Processing Oceans 8
# Processing Die Hard 2
# Processing Daddys Home 2
# Processing Wall Street 2: Money Never Sleeps
# Processing Basic Instinct 2
# Processing Ted 2
# Processing Apollo 13
# Processing Hotel Transylvania 3: Summer Vacation
# Processing The Santa Clause 2
# Processing The Angry Birds Movie 2
# Processing U571
# Processing 3000 Miles to Graceland
# Processing 2 Guns
# Processing 300
# Processing Cheaper by the Dozen 2
# Processing Ladder 49
# Processing Under Siege 2: Dark Territory
# Processing Miss Congeniality 2: Armed and Fabulous
# Processing Planet 51
# Processing The Monkey King 2
# Processing Coming 2 America
# Processing The Ridiculous 6
# Processing Kill Bill: Volume 2
# Processing Alien 3
# Processing 22 Jump Street
# Processing Anchorman 2: The Legend Continues
# Processing Super 8
# Processing How to Lose a Guy in 10 Days
# Processing 13 Hours: The Secret Soldiers of Benghazi
# Processing Gremlins 2: The New Batch
# Processing The Adventures of Sharkboy and Lavagirl in 3D
# Processing Horizon: An American Saga Chapter 1
# Processing Zoolander 2
# Processing Child 44
# Processing Horizon: An American Saga Chapter 2
# Processing Taken 3
# Processing 3:10 to Yuma
# Processing Taken 2
# Processing Scary Movie 3
# Processing Pitch Perfect 3
# Processing The Princess Diaries 2: Royal Engagement
# Processing Scary Movie 2
# Processing Peter Rabbit 2: The Runaway
# Processing 16 Blocks
# Processing 65
# Processing 28 Days
# Processing 21 Jump Street
# Processing 15 Minutes
# Processing 8 Mile
# Processing Spy Kids 3D: Game Over
# Processing The Conjuring 2: The Enfield Poltergeist
# Processing Ride Along 2
# Processing Scary Movie 4
# Processing Scream 3
# Processing 17 Again
# Processing Horrible Bosses 2
# Processing Final Destination 5
# Processing Scream 4
# Processing 8MM
# Processing Transporter 3
# Processing The Nut Job 2: Nutty by Nature
# Processing Hocus Pocus 2
# Processing Paul Blart: Mall Cop 2
# Processing 13 Going On 30
# Processing Dolphin Tale 2
# Processing Lethal Weapon 3
# Processing 21
# Processing This is 40
# Processing Neighbors 2: Sorority Rising
# Processing Goosebumps 2: Haunted Halloween
# Processing 12 Strong
# Processing Mile 22
# Processing Predator 2
# Processing Hitman: Agent 47
# Processing 21 Bridges
# Processing The Number 23
# Processing 1941
# Processing 42
# Processing American Pie 2
# Processing District 9
# Processing 27 Dresses
# Processing Naked Gun 33 13: The Final Insult
# Processing Step Up 3D
# Processing 30 Days of Night
# Processing The 15:17 to Paris
# Processing Mr. 3000
# Processing Assault On Precinct 13
# Processing Baahubali 2: The Conclusion
# Processing 88 Minutes
# Processing Pitch Perfect 2
# Processing 12 Monkeys
# Processing 80 for Brady
# Processing 30 Minutes or Less
# Processing Dracula 2000
# Processing 3 Days to Kill
# Processing Case 39
# Processing Formula 51
# Processing Final Destination 2
# Processing Agent Cody Banks 2: Destination London
# Processing Bad Santa 2
# Processing Final Destination 3
# Processing Jeepers Creepers 2
# Processing Cradle 2 the Grave
# Processing Shark Night 3D
# Processing The 33
# Processing Scream 2
# Processing Piranha 3D
# Processing Dhoom 3
# Processing The Naked Gun 2: The Smell of Fear
# Processing Jaws 4: The Revenge
# Processing 1408
# Processing RoboCop 3
# Processing Home Alone 2: Lost in New York
# Processing Jackass 3D
# Processing Jaws 2
# Processing 12 Years a Slave
# Processing The Jungle Book 2
# Processing Tyler Perrys Boo 2 A Madea Halloween
# Processing Texas Chainsaw 3D
# Processing Silent Hill: Revelation 3D
# Processing 21 Grams
# Processing Triple 9
# Processing 12 Rounds
# Processing 3 Ninjas Kick Back
# Processing CJ7
# Processing Les Couloirs du temps: Les visiteurs 2
# Processing Barbershop 2: Back in Business
# Processing My Big Fat Greek Wedding 2
# Processing United 93
# Processing Catch22
# Processing 127 Hours
# Processing T2: Trainspotting
# Processing 8 Million Ways to Die
# Processing Step Up 2 the Streets
# Processing Friday the 13th
# Processing Halloween: H2O
# Processing 40 Days and 40 Nights
# Processing 55 Days at Peking
# Processing 10 Cloverfield Lane
# Processing Dont Breathe 2
# Processing 28 Weeks Later
# Processing Book of Shadows: Blair Witch 2
# Processing U2 3D
# Processing Crocodile Dundee 2
# Processing Hot Tub Time Machine 2
# Processing Super Troopers 2
# Processing A Nightmare on Elm Street 4: The Dream Master
# Processing 21 and Over
# Processing 54
# Processing M3GAN
# Processing 47 Meters Down: Uncaged
# Processing Girl 6
# Processing 2046
# Processing 5 Days of War
# Processing 10 Days in a Madhouse
# Processing 1612
# Processing 2001: A Space Odyssey
# Processing Insidious Chapter 3
# Processing Sinister 2
# Processing Reno 911: Miami
# Processing Movie 43
# Processing 50 to 1
# Processing Police Academy 7: Mission to Moscow
# Processing The Reef
# Processing Nurse 3D
# Processing Happy Death Day 2U
# Processing Glee: The 3D Concert Movie
# Processing Hamlet 2
# Processing Beneath Hill 60
# Processing The Strangers: Chapter 1
# Processing 28 Days Later
# Processing 500 Days of Summer
# Processing Code 46
# Processing 3
# Processing House of 1000 Corpses
# Processing High School Musical 2
# Processing Fahrenheit 911
# Processing Around the World in 80 Days
# Processing Halloween 5: The Revenge of Michael Myers
# Processing 200 Cigarettes
# Processing Beastmaster 2: Through the Portal of Time
# Processing The 5th Quarter
# Processing 11:14
# Processing Khiladi 786
# Processing Rec 2
# Processing R100
# Processing 47 Meters Down
# Processing Paranormal Activity 3
# Processing Insidious Chapter 2
# Processing Paranormal Activity 4
# Processing A Nightmare On Elm Street 3: Dream Warriors
# Processing Gods Not Dead 2
# Processing House Party 2
# Processing Halloween 4: The Return of Michael Myers
# Processing Apollo 18
# Processing Force 10 from Navarone
# Processing Fahrenheit 119
# Processing 90 Minutes in Heaven
# Processing Table 19
# Processing Area 51
# Processing Psych 9
# Processing 7500
# Processing 25th Hour
# Processing A Haunted House 2
# Processing 3 Strikes
# Processing 13 Sins
# Processing Brawl in Cell Block 99
# Processing 1776
# Processing MASH
# Processing Creepshow 2
# Processing The House Next Door: Meet the Blacks 2
# Processing 2:13
# Processing Batman: The Dark Knight Returns Part 2
# Processing Class of 1984
# Processing Paranormal Activity 2
# Processing Pokemon 3: The Movie
# Processing 8 Heads in a Duffel Bag
# Processing 3 From Hell
# Processing Never Back Down 2: The Beatdown
# Processing Candyman 3: Day of the Dead
# Processing Mid90s
# Processing 2016: Obamas America
# Processing Halloween 3: Season of the Witch
# Processing 8: The Mormon Proposition
# Processing 8 Days
# Processing Thr3e
# Processing Friday the 13th Part 3
# Processing Mad Max 2: The Road Warrior
# Processing Terrifier 3
# Processing Return of the Living Dead 3
# Processing To Be Frank Sinatra at 100
# Processing 31
# Processing Session 9
# Processing DefCon 4
# Processing Friday the 13th Part 2
# Processing Godzilla 2000
# Processing 20 Feet From Stardom
# Processing 23 Blast
# Processing 16 to Life
# Processing 1982
# Processing 40 Weeks
# Processing Friday the 13th
# Processing Scott Walker: 30 Century Man
# Processing 42nd Street
# Processing Short Term 12
# Processing American Ninja 2: The Confrontation
# Processing 51 Birch Street
# Processing Rotor DR1
# Processing 3 Backyards
# Processing Locker 13
# Processing Death Race 2000
# Processing Terrifier 2
# Processing 411
# Processing The Beast from 20000 Fathoms
# Processing Antarctic Edge: 70 South
# Processing 8 Days to Hell
# Processing 20 Dates
# Processing Happy 40th
# Processing Red 11
#                               Name                   Year CriticScore  \
# 0                      SpiderMan 3   Released May 4, 2007         63%
# 1    Guardians of the Galaxy Vol 3   Released May 5, 2023         82%
# 2                       Iron Man 3   Released May 3, 2013         79%
# 3    Guardians of the Galaxy Vol 2   Released May 5, 2017         85%
# 4                      SpiderMan 2  Released Jun 30, 2004         93%
# ..                             ...                    ...         ...
# 318       Antarctic Edge: 70 South  Released Apr 17, 2015         57%
# 319                 8 Days to Hell                   2021
# 320                       20 Dates  Released Feb 26, 1999         35%
# 321                     Happy 40th                   2015
# 322                         Red 11                   2019         67%
#
#     UserScore                                               Link  \
# 0         51%       https://www.rottentomatoes.com/m/spiderman_3
# 1         94%  https://www.rottentomatoes.com/m/guardians_of_...
# 2         78%        https://www.rottentomatoes.com/m/iron_man_3
# 3         87%  https://www.rottentomatoes.com/m/guardians_of_...
# 4         82%       https://www.rottentomatoes.com/m/spiderman_2
# ..        ...                                                ...
# 318       50%  https://www.rottentomatoes.com/m/antarctic_edg...
# 319              https://www.rottentomatoes.com/m/8_days_to_hell
# 320       47%          https://www.rottentomatoes.com/m/20_dates
# 321                  https://www.rottentomatoes.com/m/happy_40th
# 322       67%            https://www.rottentomatoes.com/m/red_11
#
#     PlatformReleased                                               Cast  \
# 0             Cinema  Tobey Maguire, Kirsten Dunst, James Franco, Th...
# 1             Cinema  Chris Pratt, Zoe Saldana, Dave Bautista, Karen...
# 2             Cinema  Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...
# 3             Cinema  Chris Pratt, Zoe Saldana, Bradley Cooper, Dave...
# 4             Cinema  Tobey Maguire, Kirsten Dunst, James Franco, Al...
# ..               ...                                                ...
# 318           Cinema        Dena Seidel, Richard Ludescher, Dena Seidel
# 319           Cinema  Eric Roberts, Shane Woodson, Drew Hale, David ...
# 320           Cinema  Myles Berkowitz, Elisabeth Wagner, Richard Arl...
# 321           Cinema  Fernando Acosta, Jenni Blong, Robyn Cohen, Mad...
# 322           Cinema  Roby Attal, Lauren Hatfield, Carlos Gallardo, ...
#
#              Director                                       Genre Rating  \
# 0           Sam Raimi                  Action, Fantasy, Adventure  PG-13
# 1          James Gunn  Sci-Fi, Adventure, Action, Fantasy, Comedy  PG-13
# 2         Shane Black          Action, Adventure, Sci-Fi, Fantasy  PG-13
# 3          James Gunn  Sci-Fi, Adventure, Action, Fantasy, Comedy  PG-13
# 4           Sam Raimi                  Action, Adventure, Fantasy  PG-13
# ..                ...                                         ...    ...
# 318       Dena Seidel                      Documentary, Adventure    N/A
# 319     Shane Woodson                                      Horror    N/A
# 320   Myles Berkowitz                             Comedy, Romance      R
# 321      Madoka Raine                                       Drama    N/A
# 322  Robert Rodriguez          Horror, Sci-Fi, Mystery & Thriller    N/A
#
#     Runtime                       Studio
# 0    2h 13m  Sony Pictures Entertainment
# 1    2h 30m         Walt Disney Pictures
# 2    2h 10m                  Walt Disney
# 3    2h 15m         Walt Disney Pictures
# 4     2h 2m  Sony Pictures Entertainment
# ..      ...                          ...
# 318  1h 12m                    First Run
# 319  1h 25m         Pegasus Flying Films
# 320  1h 32m                          Fox
# 321  1h 40m                      English
# 322  1h 17m         Double R Productions
#
# [323 rows x 12 columns]

# %%
movies_data_updated = pd.read_csv('../../Data/updated_movies.csv')
movies_data_final = pd.concat([movies_data_updated, movies_data], ignore_index=True)
movies_data_final
# Out:
#                           Name                   Year CriticScore UserScore  \
# 0            L.A. Confidential                 (1997)         99%       94%
# 1                The Godfather                 (1972)         97%       98%
# 2                   Casablanca                 (1942)         99%       95%
# 3                     Parasite                 (2019)         99%       90%
# 4             Schindler's List                 (1993)         98%       97%
# ...                        ...                    ...         ...       ...
# 5183  Antarctic Edge: 70 South  Released Apr 17, 2015         57%       50%
# 5184            8 Days to Hell                   2021
# 5185                  20 Dates  Released Feb 26, 1999         35%       47%
# 5186                Happy 40th                   2015
# 5187                    Red 11                   2019         67%       67%
#
#                                                    Link PlatformReleased  \
# 0      https://www.rottentomatoes.com/m/la_confidential           Cinema
# 1        https://www.rottentomatoes.com/m/the_godfather           Cinema
# 2     https://www.rottentomatoes.com/m/1003707-casab...           Cinema
# 3        https://www.rottentomatoes.com/m/parasite_2019           Cinema
# 4      https://www.rottentomatoes.com/m/schindlers_list           Cinema
# ...                                                 ...              ...
# 5183  https://www.rottentomatoes.com/m/antarctic_edg...           Cinema
# 5184    https://www.rottentomatoes.com/m/8_days_to_hell           Cinema
# 5185          https://www.rottentomatoes.com/m/20_dates           Cinema
# 5186        https://www.rottentomatoes.com/m/happy_40th           Cinema
# 5187            https://www.rottentomatoes.com/m/red_11           Cinema
#
#                                                    Cast              Director  \
# 0     Kevin Spacey, Russell Crowe, Guy Pearce, James...         Curtis Hanson
# 1     Marlon Brando, Al Pacino, James Caan, Richard ...  Francis Ford Coppola
# 2     Humphrey Bogart, Ingrid Bergman, Paul Henreid,...        Michael Curtiz
# 3     Song Kang-ho, Lee Sun-kyun, Jo Yeo-jeong, Choi...          Bong Joon Ho
# 4     Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...      Steven Spielberg
# ...                                                 ...                   ...
# 5183        Dena Seidel, Richard Ludescher, Dena Seidel           Dena Seidel
# 5184  Eric Roberts, Shane Woodson, Drew Hale, David ...         Shane Woodson
# 5185  Myles Berkowitz, Elisabeth Wagner, Richard Arl...       Myles Berkowitz
# 5186  Fernando Acosta, Jenni Blong, Robyn Cohen, Mad...          Madoka Raine
# 5187  Roby Attal, Lauren Hatfield, Carlos Gallardo, ...      Robert Rodriguez
#
#                                    Genre Rating Runtime                 Studio
# 0                           Crime, Drama      R  2h 16m      Warner Home Vídeo
# 1                           Crime, Drama      R  2h 57m     Paramount Pictures
# 2                                  Drama     PG  1h 42m  Warner Bros. Pictures
# 3      Comedy, Mystery & Thriller, Drama      R  2h 12m                   Neon
# 4                         History, Drama      R  3h 15m     Universal Pictures
# ...                                  ...    ...     ...                    ...
# 5183              Documentary, Adventure    N/A  1h 12m              First Run
# 5184                              Horror    N/A  1h 25m   Pegasus Flying Films
# 5185                     Comedy, Romance      R  1h 32m                    Fox
# 5186                               Drama    N/A  1h 40m                English
# 5187  Horror, Sci-Fi, Mystery & Thriller    N/A  1h 17m   Double R Productions
#
# [5188 rows x 12 columns]

# %%
movies_data_final.to_csv('../../Data/final_movies.csv', index=False)

# %%
movies_data_final = pd.read_csv('../../Data/final_movies.csv')
movies_data_final
# Out:
#                       Name                   Year CriticScore UserScore  \
# 0           LAConfidential                 (1997)         99%       94%
# 1             TheGodfather                 (1972)         97%       98%
# 2               Casablanca                 (1942)         99%       95%
# 3                 Parasite                 (2019)         99%       90%
# 4           SchindlersList                 (1993)         98%       97%
# ...                    ...                    ...         ...       ...
# 5183  AntarcticEdge70South  Released Apr 17, 2015         57%       50%
# 5184           8DaystoHell                   2021         NaN       NaN
# 5185               20Dates  Released Feb 26, 1999         35%       47%
# 5186             Happy40th                   2015         NaN       NaN
# 5187                 Red11                   2019         67%       67%
#
#                                                    Link PlatformReleased  \
# 0      https://www.rottentomatoes.com/m/la_confidential           Cinema
# 1        https://www.rottentomatoes.com/m/the_godfather           Cinema
# 2     https://www.rottentomatoes.com/m/1003707-casab...           Cinema
# 3        https://www.rottentomatoes.com/m/parasite_2019           Cinema
# 4      https://www.rottentomatoes.com/m/schindlers_list           Cinema
# ...                                                 ...              ...
# 5183  https://www.rottentomatoes.com/m/antarctic_edg...           Cinema
# 5184    https://www.rottentomatoes.com/m/8_days_to_hell           Cinema
# 5185          https://www.rottentomatoes.com/m/20_dates           Cinema
# 5186        https://www.rottentomatoes.com/m/happy_40th           Cinema
# 5187            https://www.rottentomatoes.com/m/red_11           Cinema
#
#                                                    Cast              Director  \
# 0     Kevin Spacey, Russell Crowe, Guy Pearce, James...         Curtis Hanson
# 1     Marlon Brando, Al Pacino, James Caan, Richard ...  Francis Ford Coppola
# 2     Humphrey Bogart, Ingrid Bergman, Paul Henreid,...        Michael Curtiz
# 3     Song Kang-ho, Lee Sun-kyun, Jo Yeo-jeong, Choi...          Bong Joon Ho
# 4     Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...      Steven Spielberg
# ...                                                 ...                   ...
# 5183        Dena Seidel, Richard Ludescher, Dena Seidel           Dena Seidel
# 5184  Eric Roberts, Shane Woodson, Drew Hale, David ...         Shane Woodson
# 5185  Myles Berkowitz, Elisabeth Wagner, Richard Arl...       Myles Berkowitz
# 5186  Fernando Acosta, Jenni Blong, Robyn Cohen, Mad...          Madoka Raine
# 5187  Roby Attal, Lauren Hatfield, Carlos Gallardo, ...      Robert Rodriguez
#
#                                    Genre Rating Runtime                 Studio
# 0                           Crime, Drama      R  2h 16m      Warner Home Vídeo
# 1                           Crime, Drama      R  2h 57m     Paramount Pictures
# 2                                  Drama     PG  1h 42m  Warner Bros. Pictures
# 3      Comedy, Mystery & Thriller, Drama      R  2h 12m                   Neon
# 4                         History, Drama      R  3h 15m     Universal Pictures
# ...                                  ...    ...     ...                    ...
# 5183              Documentary, Adventure    NaN  1h 12m              First Run
# 5184                              Horror    NaN  1h 25m   Pegasus Flying Films
# 5185                     Comedy, Romance      R  1h 32m                    Fox
# 5186                               Drama    NaN  1h 40m                English
# 5187  Horror, Sci-Fi, Mystery & Thriller    NaN  1h 17m   Double R Productions
#
# [5188 rows x 12 columns]
